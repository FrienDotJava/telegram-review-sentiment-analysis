# %%
import pandas as pd
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
scrapreview = reviews_all(
    'org.telegram.messenger',          
    lang='id',             
    country='id',          
    sort=Sort.MOST_RELEVANT, 
    count=1000             
)

# %%
app_reviews_df = pd.DataFrame(scrapreview)

app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  9d95e21b-cf1d-4c27-b7db-31df13d8569a  Pengguna Google
# 1  fc828663-e951-4509-b0da-c0a810a92bf0  Pengguna Google
# 2  1a89aa6d-4c1e-49e2-8802-0b35f4521127  Pengguna Google
# 3  970a0e27-163e-44b3-9b45-7fa338be7222  Pengguna Google
# 4  371f7a0e-5311-4089-9671-328758442052  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Versi sekarang cuma bisa chatting aja, biasany...      2            741
# 1  Bagusan settingan dulu, yg bisa layar ambang k...      2            273
# 2  Hampir semua fitur harus berlangganan ke premi...      1           1360
# 3  Ini gimana mau login g bisa2! Kode g dikirim2 ...      1           1000
# 4  Parah sejak update kenapa malah lelet terus, j...      1            323
#
#   reviewCreatedVersion                  at  \
# 0               11.7.4 2025-03-04 14:25:09
# 1               11.7.4 2025-03-04 16:40:59
# 2               11.8.2 2025-03-14 22:22:27
# 3               11.7.4 2025-03-06 17:21:18
# 4               11.7.4 2025-03-04 09:23:03
#
#                                         replyContent           repliedAt  \
# 0  We're sorry to hear that. Please verify that y... 2025-03-04 15:03:17
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0     11.7.4
# 1     11.7.4
# 2     11.8.2
# 3     11.7.4
# 4     11.7.4

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63000 entries, 0 to 62999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              63000 non-null  object
#  1   userName              63000 non-null  object
#  2   userImage             63000 non-null  object
#  3   content               63000 non-null  object
#  4   score                 63000 non-null  int64
#  5   thumbsUpCount         63000 non-null  int64
#  6   reviewCreatedVersion  44894 non-null  object
#  7   at                    63000 non-null  datetime64[ns]
#  8   replyContent          6511 non-null   object
#  9   repliedAt             6511 non-null   datetime64[ns]
#  10  appVersion            44894 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
app_reviews_df.to_csv("telegram-review.csv")
